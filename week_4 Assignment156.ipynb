# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


df=pd.read_csv('heart_failure_clinical_records_dataset.csv')
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
print(df.loc[2,'age'])

print(df.iloc[2,0])
# Out:
# 65.0
# 65.0

# %%
df.sort_values("creatinine_phosphokinase")
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 31   85.0        0                        23         0                 45
# 151  62.0        0                        30         1                 60
# 5    90.0        1                        47         0                 40
# 75   60.0        1                        47         0                 20
# 86   55.0        0                        47         0                 35
# ..    ...      ...                       ...       ...                ...
# 134  81.0        0                      4540         0                 35
# 103  42.0        0                      5209         0                 30
# 72   85.0        0                      5882         0                 35
# 60   45.0        0                      7702         1                 25
# 1    55.0        0                      7861         0                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 31                     0  360000.00              3.00           132    1
# 151                    1  244000.00              0.90           139    1
# 5                      1  204000.00              2.10           132    1
# 75                     0  204000.00              0.70           139    1
# 86                     1  173000.00              1.10           137    1
# ..                   ...        ...               ...           ...  ...
# 134                    0  231000.00              1.18           137    1
# 103                    0  226000.00              1.00           140    1
# 72                     0  243000.00              1.00           132    1
# 60                     1  390000.00              1.00           139    1
# 1                      0  263358.03              1.10           136    1
#
#      smoking  time  DEATH_EVENT
# 31         0    28            1
# 151        0   117            0
# 5          1     8            1
# 75         1    73            1
# 86         0    79            0
# ..       ...   ...          ...
# 134        1   107            0
# 103        1    87            0
# 72         1    72            1
# 60         0    60            1
# 1          0     6            1
#
# [299 rows x 13 columns]

# %%
df1=df.copy()
df1.groupby("creatinine_phosphokinase").mean()
# Out:
#                                 age   anaemia  diabetes  ejection_fraction  \
# creatinine_phosphokinase
# 23                        85.000000  0.000000       0.0          45.000000
# 30                        62.000000  0.000000       1.0          60.000000
# 47                        68.333333  0.666667       0.0          31.666667
# 52                        65.000000  1.000000       0.0          25.000000
# 53                        60.000000  0.000000       0.0          50.000000
# ...                             ...       ...       ...                ...
# 4540                      81.000000  0.000000       0.0          35.000000
# 5209                      42.000000  0.000000       0.0          30.000000
# 5882                      85.000000  0.000000       0.0          35.000000
# 7702                      45.000000  0.000000       1.0          25.000000
# 7861                      55.000000  0.000000       0.0          38.000000
#
#                           high_blood_pressure      platelets  \
# creatinine_phosphokinase
# 23                                   0.000000  360000.000000
# 30                                   1.000000  244000.000000
# 47                                   0.666667  193666.666667
# 52                                   1.000000  276000.000000
# 53                                   1.000000  286000.000000
# ...                                       ...            ...
# 4540                                 0.000000  231000.000000
# 5209                                 0.000000  226000.000000
# 5882                                 0.000000  243000.000000
# 7702                                 1.000000  390000.000000
# 7861                                 0.000000  263358.030000
#
#                           serum_creatinine  serum_sodium  sex   smoking  \
# creatinine_phosphokinase
# 23                                    3.00         132.0  1.0  0.000000
# 30                                    0.90         139.0  1.0  0.000000
# 47                                    1.30         136.0  1.0  0.666667
# 52                                    1.30         137.0  0.0  0.000000
# 53                                    2.30         143.0  0.0  0.000000
# ...                                    ...           ...  ...       ...
# 4540                                  1.18         137.0  1.0  1.000000
# 5209                                  1.00         140.0  1.0  1.000000
# 5882                                  1.00         132.0  1.0  1.000000
# 7702                                  1.00         139.0  1.0  0.000000
# 7861                                  1.10         136.0  1.0  0.000000
#
#                                 time  DEATH_EVENT
# creatinine_phosphokinase
# 23                         28.000000     1.000000
# 30                        117.000000     0.000000
# 47                         53.333333     0.666667
# 52                         16.000000     0.000000
# 53                         87.000000     0.000000
# ...                              ...          ...
# 4540                      107.000000     0.000000
# 5209                       87.000000     0.000000
# 5882                       72.000000     1.000000
# 7702                       60.000000     1.000000
# 7861                        6.000000     1.000000
#
# [208 rows x 12 columns]

# %%
df.isnull()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium    sex  \
# 0                  False      False             False         False  False
# 1                  False      False             False         False  False
# 2                  False      False             False         False  False
# 3                  False      False             False         False  False
# 4                  False      False             False         False  False
# ..                   ...        ...               ...           ...    ...
# 294                False      False             False         False  False
# 295                False      False             False         False  False
# 296                False      False             False         False  False
# 297                False      False             False         False  False
# 298                False      False             False         False  False
#
#      smoking   time  DEATH_EVENT
# 0      False  False        False
# 1      False  False        False
# 2      False  False        False
# 3      False  False        False
# 4      False  False        False
# ..       ...    ...          ...
# 294    False  False        False
# 295    False  False        False
# 296    False  False        False
# 297    False  False        False
# 298    False  False        False
#
# [299 rows x 13 columns]

# %%
sns.boxplot(x=df["age"])
plt.show()

sns.boxplot(x=df["anaemia"])
plt.show()

sns.boxplot(x=df["creatinine_phosphokinase"])
plt.show()

# %%
df["age"].hist(bins=50)
plt.xlabel("AGE")
plt.show()

df["creatinine_phosphokinase"].hist(bins=50)
plt.xlabel("creatinine_phosphokinase")
plt.show()

# %%
z_scores = np.abs(stats.zscore(df["creatinine_phosphokinase"]))
outliers_z = df[z_scores > 3]
print(outliers_z.shape)
# Out:
# (7, 13)

# %%
Q1 = df["creatinine_phosphokinase"].quantile(0.25)
Q3 = df["creatinine_phosphokinase"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_iqr = df[(df["creatinine_phosphokinase"] < lower_bound) | (df["creatinine_phosphokinase"] > upper_bound)]
print(outliers_iqr.shape)
# Out:
# (29, 13)

# %%
df_removed = df[(df["creatinine_phosphokinase"] >= lower_bound) & (df["creatinine_phosphokinase"] <= upper_bound)]
print(df_removed.shape)
# Out:
# (270, 13)

# %%
outliers_iqr1 = df_removed[(df_removed["creatinine_phosphokinase"] < lower_bound) | (df_removed["creatinine_phosphokinase"] > upper_bound)]
print(outliers_iqr1.shape)
# Out:
# (0, 13)

# %%
df_capped = df.copy()
df_capped["creatinine_phosphokinase"] = np.where(df_capped["creatinine_phosphokinase"] > upper_bound, upper_bound,
                                    np.where(df_capped["creatinine_phosphokinase"] < lower_bound, lower_bound, df_capped["creatinine_phosphokinase"]))

# %%
outliers_iqr2 = df_capped[(df_capped["creatinine_phosphokinase"] < lower_bound) | (df_capped["creatinine_phosphokinase"] > upper_bound)]
print(outliers_iqr2.shape)
# Out:
# (0, 13)

# %%
df_log = df.copy()
df_log["creatinine_phosphokinase"] = np.log(df_log["creatinine_phosphokinase"] + 1)  # adding 1 to avoid log(0)

# %%
outliers_iqr3 = df_log[(df_capped["creatinine_phosphokinase"] < lower_bound) | (df_log["creatinine_phosphokinase"] > upper_bound)]
print(outliers_iqr3.shape)
# Out:
# (0, 13)

# %%
df_imp = df.copy()
median_value = df["creatinine_phosphokinase"].median()
df_imp.loc[(df_imp["creatinine_phosphokinase"] > upper_bound) | (df_imp["creatinine_phosphokinase"] < lower_bound), "creatinine_phosphokinase"] = median_value

# %%
outliers_iqr4 = df_imp[(df_capped["creatinine_phosphokinase"] < lower_bound) | (df_imp["creatinine_phosphokinase"] > upper_bound)]
print(outliers_iqr4.shape)
# Out:
# (0, 13)

# %%
df.to_csv("output.csv",index=True)
